# %%
import pandas as pd
import requests
import gmaps
import random
import numpy as np
from citipy import citipy
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(-90.00,90.00,2000)
lngs = np.random.uniform(-180.00,180.00, 2000)
lats_lngs = zip(lats,lngs)
coordinates = list(lats_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 782

# %%
# Check
check_url = url + "&q=Miami"
city_data_check = requests.get(check_url).json()
city_data_check
# Out:
# {'coord': {'lon': -80.1937, 'lat': 25.7743},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 85.21,
#   'feels_like': 95.22,
#   'temp_min': 82.98,
#   'temp_max': 87.8,
#   'pressure': 1017,
#   'humidity': 75},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 0, 'gust': 8.99},
#  'clouds': {'all': 90},
#  'dt': 1624050450,
#  'sys': {'type': 2,
#   'id': 2009435,
#   'country': 'US',
#   'sunrise': 1624012175,
#   'sunset': 1624061663},
#  'timezone': -14400,
#  'id': 4164138,
#  'name': 'Miami',
#  'cod': 200}

# %% [markdown]
# # Retrieve data

# %%
# Retrieve info from all cities
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print("------------------------------")

# Counters for 50 cities in 10 sets for the 500 total
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descript = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | korla
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | saint anthony
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | haines junction
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | rongcheng
# Processing Record 8 of Set 1 | novaya zaimka
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | nyimba
# Processing Record 11 of Set 1 | havelock
# Processing Record 12 of Set 1 | imbituba
# Processing Record 13 of Set 1 | kenai
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | padang
# Processing Record 20 of Set 1 | evensk
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | kachiry
# Processing Record 24 of Set 1 | pecos
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | flers
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | kamina
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | vallenar
# Processing Record 31 of Set 1 | malartic
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | ginir
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | bayir
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 1 | sosnogorsk
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | labuhan
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | pittsfield
# Processing Record 47 of Set 1 | kologriv
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | jinchang
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | liberal
# Processing Record 2 of Set 2 | esso
# Processing Record 3 of Set 2 | mitsamiouli
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 2 | londonderry
# Processing Record 7 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 2 | oparino
# Processing Record 9 of Set 2 | acajutla
# Processing Record 10 of Set 2 | kuji
# Processing Record 11 of Set 2 | baruun-urt
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | nurota
# Processing Record 15 of Set 2 | ust-omchug
# Processing Record 16 of Set 2 | aklavik
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 2 | el alto
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | esperance
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | dingle
# Processing Record 28 of Set 2 | sobolevo
# Processing Record 29 of Set 2 | camacha
# Processing Record 30 of Set 2 | maracacume
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | comodoro rivadavia
# Processing Record 33 of Set 2 | los llanos de aridane
# Processing Record 34 of Set 2 | sandpoint
# Processing Record 35 of Set 2 | storslett
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | hobyo
# Processing Record 40 of Set 2 | kaduna
# Processing Record 41 of Set 2 | kattivakkam
# Processing Record 42 of Set 2 | payo
# Processing Record 43 of Set 2 | cabedelo
# Processing Record 44 of Set 2 | qaanaaq
# Processing Record 45 of Set 2 | dawson creek
# Processing Record 46 of Set 2 | tautira
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | hami
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | rocha
# Processing Record 5 of Set 3 | muros
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | buraydah
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | faanui
# Processing Record 11 of Set 3 | natal
# Processing Record 12 of Set 3 | ndjole
# Processing Record 13 of Set 3 | bluff
# Processing Record 14 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 3 | launceston
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | puerto leguizamo
# Processing Record 18 of Set 3 | yar-sale
# Processing Record 19 of Set 3 | hamilton
# Processing Record 20 of Set 3 | harper
# Processing Record 21 of Set 3 | sao miguel do araguaia
# Processing Record 22 of Set 3 | oranjestad
# Processing Record 23 of Set 3 | severo-yeniseyskiy
# Processing Record 24 of Set 3 | leningradskiy
# Processing Record 25 of Set 3 | zarubino
# Processing Record 26 of Set 3 | arman
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | kumluca
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | tuktoyaktuk
# Processing Record 33 of Set 3 | fort nelson
# Processing Record 34 of Set 3 | qaqortoq
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | zhezkazgan
# Processing Record 37 of Set 3 | magadan
# Processing Record 38 of Set 3 | rovaniemi
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 3 | chifeng
# Processing Record 43 of Set 3 | meiktila
# Processing Record 44 of Set 3 | myitkyina
# Processing Record 45 of Set 3 | trinidad
# Processing Record 46 of Set 3 | opaka
# Processing Record 47 of Set 3 | puerto madryn
# Processing Record 48 of Set 3 | kristiinankaupunki
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | deputatskiy
# Processing Record 1 of Set 4 | high rock
# Processing Record 2 of Set 4 | pavilosta
# Processing Record 3 of Set 4 | faya
# Processing Record 4 of Set 4 | baganga
# Processing Record 5 of Set 4 | tura
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | rabo de peixe
# Processing Record 8 of Set 4 | gimli
# Processing Record 9 of Set 4 | barabai
# Processing Record 10 of Set 4 | broken hill
# Processing Record 11 of Set 4 | katsuura
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | vao
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | santiago de cao
# Processing Record 16 of Set 4 | piranhas
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | jaitaran
# Processing Record 19 of Set 4 | olawa
# Processing Record 20 of Set 4 | saint-georges
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | havoysund
# Processing Record 23 of Set 4 | sierpc
# Processing Record 24 of Set 4 | iquitos
# Processing Record 25 of Set 4 | pampas
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | sibolga
# Processing Record 28 of Set 4 | akhtubinsk
# Processing Record 29 of Set 4 | tabou
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | dikson
# Processing Record 32 of Set 4 | grand forks
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | ocos
# Processing Record 35 of Set 4 | muscat
# Processing Record 36 of Set 4 | kingsport
# Processing Record 37 of Set 4 | mirnyy
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | chaohu
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | walvis bay
# Processing Record 44 of Set 4 | palembang
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | maine-soroa
# Processing Record 48 of Set 4 | torbat-e jam
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | souillac
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | arraial do cabo
# Processing Record 6 of Set 5 | zalantun
# Processing Record 7 of Set 5 | nagato
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | najran
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | salinopolis
# Processing Record 12 of Set 5 | jadu
# Processing Record 13 of Set 5 | roscommon
# Processing Record 14 of Set 5 | torbay
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | matay
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | coruripe
# Processing Record 19 of Set 5 | koumac
# Processing Record 20 of Set 5 | severo-kurilsk
# Processing Record 21 of Set 5 | moyale
# Processing Record 22 of Set 5 | meulaboh
# Processing Record 23 of Set 5 | sarangani
# Processing Record 24 of Set 5 | bonoua
# Processing Record 25 of Set 5 | hualmay
# Processing Record 26 of Set 5 | qui nhon
# Processing Record 27 of Set 5 | vanderhoof
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | zhigansk
# Processing Record 30 of Set 5 | freeport
# Processing Record 31 of Set 5 | tsaratanana
# Processing Record 32 of Set 5 | kaeo
# Processing Record 33 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | amalapuram
# Processing Record 35 of Set 5 | kavieng
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | kushima
# Processing Record 38 of Set 5 | imeni poliny osipenko
# Processing Record 39 of Set 5 | hithadhoo
# Processing Record 40 of Set 5 | mokhsogollokh
# Processing Record 41 of Set 5 | carutapera
# Processing Record 42 of Set 5 | vanimo
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | tierranueva
# Processing Record 45 of Set 5 | asopos
# Processing Record 46 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 5 | lompoc
# Processing Record 48 of Set 5 | wuwei
# Processing Record 49 of Set 5 | tiksi
# Processing Record 50 of Set 5 | moindou
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | soure
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | gorin
# Processing Record 5 of Set 6 | zaysan
# Processing Record 6 of Set 6 | oconomowoc
# Processing Record 7 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 6 | qasigiannguit
# Processing Record 9 of Set 6 | arroyo
# Processing Record 10 of Set 6 | lubin
# Processing Record 11 of Set 6 | huarmey
# Processing Record 12 of Set 6 | preeceville
# Processing Record 13 of Set 6 | saint-francois
# Processing Record 14 of Set 6 | montes altos
# Processing Record 15 of Set 6 | karpathos
# Processing Record 16 of Set 6 | moses lake
# Processing Record 17 of Set 6 | ancud
# Processing Record 18 of Set 6 | margate
# Processing Record 19 of Set 6 | birsk
# Processing Record 20 of Set 6 | sulphur
# Processing Record 21 of Set 6 | westport
# Processing Record 22 of Set 6 | hollola
# Processing Record 23 of Set 6 | kununurra
# Processing Record 24 of Set 6 | tubmanburg
# Processing Record 25 of Set 6 | matara
# Processing Record 26 of Set 6 | bousso
# Processing Record 27 of Set 6 | abu dhabi
# Processing Record 28 of Set 6 | grand gaube
# Processing Record 29 of Set 6 | iwaki
# Processing Record 30 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 6 | burnie
# Processing Record 32 of Set 6 | aksarka
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | victor harbor
# Processing Record 36 of Set 6 | bara
# Processing Record 37 of Set 6 | san jose
# Processing Record 38 of Set 6 | krasnyy yar
# Processing Record 39 of Set 6 | butaritari
# Processing Record 40 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 6 | iwanai
# Processing Record 42 of Set 6 | sfantu gheorghe
# Processing Record 43 of Set 6 | bathsheba
# Processing Record 44 of Set 6 | california city
# Processing Record 45 of Set 6 | praia da vitoria
# Processing Record 46 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 6 | christchurch
# Processing Record 49 of Set 6 | sabinopolis
# Processing Record 50 of Set 6 | sitka
# Processing Record 1 of Set 7 | muroto
# Processing Record 2 of Set 7 | mecca
# Processing Record 3 of Set 7 | olavarria
# Processing Record 4 of Set 7 | luanda
# Processing Record 5 of Set 7 | mogadishu
# Processing Record 6 of Set 7 | cheremukhovo
# Processing Record 7 of Set 7 | coahuayana
# Processing Record 8 of Set 7 | pemba
# Processing Record 9 of Set 7 | kanniyakumari
# Processing Record 10 of Set 7 | villarrobledo
# Processing Record 11 of Set 7 | dawei
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | galesong
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | talnakh
# Processing Record 17 of Set 7 | alta floresta
# Processing Record 18 of Set 7 | solenzo
# Processing Record 19 of Set 7 | mafeteng
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | sur
# Processing Record 22 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 7 | ostersund
# Processing Record 24 of Set 7 | ouadda
# Processing Record 25 of Set 7 | boende
# Processing Record 26 of Set 7 | tucupita
# Processing Record 27 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 28 of Set 7 | akyab
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | maningrida
# Processing Record 31 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 7 | zhuozhou
# City not found. Skipping...
# Processing Record 33 of Set 7 | ruwi
# Processing Record 34 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 7 | tucumcari
# Processing Record 37 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | egvekinot
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | houma
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | wanning
# Processing Record 46 of Set 7 | pinega
# Processing Record 47 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 7 | ondangwa
# Processing Record 49 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 7 | portland
# Processing Record 1 of Set 8 | sao felix do xingu
# Processing Record 2 of Set 8 | aykhal
# Processing Record 3 of Set 8 | dabat
# Processing Record 4 of Set 8 | chokurdakh
# Processing Record 5 of Set 8 | muti
# Processing Record 6 of Set 8 | bad bevensen
# Processing Record 7 of Set 8 | praia
# Processing Record 8 of Set 8 | yantai
# Processing Record 9 of Set 8 | palmer
# Processing Record 10 of Set 8 | san ramon
# Processing Record 11 of Set 8 | morden
# Processing Record 12 of Set 8 | huai thalaeng
# Processing Record 13 of Set 8 | fortuna
# Processing Record 14 of Set 8 | ahipara
# Processing Record 15 of Set 8 | nanortalik
# Processing Record 16 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 8 | cockburn town
# Processing Record 18 of Set 8 | rumuruti
# Processing Record 19 of Set 8 | marsh harbour
# Processing Record 20 of Set 8 | victoria
# Processing Record 21 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 8 | isla mujeres
# Processing Record 23 of Set 8 | ntungamo
# Processing Record 24 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | panaba
# Processing Record 27 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 8 | vostok
# Processing Record 29 of Set 8 | bambanglipuro
# Processing Record 30 of Set 8 | belyy yar
# Processing Record 31 of Set 8 | malindi
# Processing Record 32 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | el viejo
# Processing Record 35 of Set 8 | ilulissat
# Processing Record 36 of Set 8 | ambanja
# Processing Record 37 of Set 8 | ulaanbaatar
# Processing Record 38 of Set 8 | pokhara
# Processing Record 39 of Set 8 | te anau
# Processing Record 40 of Set 8 | trapani
# Processing Record 41 of Set 8 | naifaru
# Processing Record 42 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 8 | leeton
# Processing Record 44 of Set 8 | alofi
# Processing Record 45 of Set 8 | manica
# Processing Record 46 of Set 8 | eganville
# Processing Record 47 of Set 8 | soyo
# Processing Record 48 of Set 8 | belaya gora
# Processing Record 49 of Set 8 | buala
# Processing Record 50 of Set 8 | bagua grande
# Processing Record 1 of Set 9 | yashan
# Processing Record 2 of Set 9 | cordoba
# Processing Record 3 of Set 9 | olafsvik
# Processing Record 4 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 9 | yertsevo
# Processing Record 6 of Set 9 | zhangye
# Processing Record 7 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 9 | la palma
# Processing Record 9 of Set 9 | abu samrah
# Processing Record 10 of Set 9 | vylkove
# Processing Record 11 of Set 9 | urusha
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | yambio
# Processing Record 14 of Set 9 | nanpara
# Processing Record 15 of Set 9 | havre
# Processing Record 16 of Set 9 | altay
# Processing Record 17 of Set 9 | tarancon
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | labuan
# Processing Record 20 of Set 9 | erzin
# Processing Record 21 of Set 9 | kimbe
# Processing Record 22 of Set 9 | caravelas
# Processing Record 23 of Set 9 | shelburne
# Processing Record 24 of Set 9 | omboue
# Processing Record 25 of Set 9 | swan river
# Processing Record 26 of Set 9 | grindavik
# Processing Record 27 of Set 9 | vanavara
# Processing Record 28 of Set 9 | whitehorse
# Processing Record 29 of Set 9 | mahajanga
# Processing Record 30 of Set 9 | itoman
# Processing Record 31 of Set 9 | catarman
# Processing Record 32 of Set 9 | verkhnyaya inta
# Processing Record 33 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 9 | kijang
# Processing Record 35 of Set 9 | termiz
# Processing Record 36 of Set 9 | rock sound
# Processing Record 37 of Set 9 | calama
# Processing Record 38 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 9 | den helder
# Processing Record 40 of Set 9 | paamiut
# Processing Record 41 of Set 9 | kulhudhuffushi
# Processing Record 42 of Set 9 | fukue
# Processing Record 43 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 9 | yerbogachen
# Processing Record 45 of Set 9 | geraldton
# Processing Record 46 of Set 9 | nouadhibou
# Processing Record 47 of Set 9 | krasnoselkup
# Processing Record 48 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 9 | beyneu
# Processing Record 50 of Set 9 | vaitape
# Processing Record 1 of Set 10 | oranjemund
# Processing Record 2 of Set 10 | tazovskiy
# Processing Record 3 of Set 10 | trelew
# Processing Record 4 of Set 10 | brae
# Processing Record 5 of Set 10 | pallasovka
# Processing Record 6 of Set 10 | saint-joseph
# Processing Record 7 of Set 10 | tahoua
# Processing Record 8 of Set 10 | ardakan
# Processing Record 9 of Set 10 | murmashi
# Processing Record 10 of Set 10 | mount isa
# Processing Record 11 of Set 10 | cooma
# Processing Record 12 of Set 10 | asfi
# Processing Record 13 of Set 10 | kahului
# Processing Record 14 of Set 10 | itaberai
# Processing Record 15 of Set 10 | yushu
# Processing Record 16 of Set 10 | port hardy
# Processing Record 17 of Set 10 | little current
# Processing Record 18 of Set 10 | alice springs
# Processing Record 19 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | coihaique
# Processing Record 21 of Set 10 | pacific grove
# Processing Record 22 of Set 10 | cobija
# Processing Record 23 of Set 10 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 24 of Set 10 | galle
# Processing Record 25 of Set 10 | filadelfia
# Processing Record 26 of Set 10 | opuwo
# Processing Record 27 of Set 10 | mareeba
# Processing Record 28 of Set 10 | biltine
# Processing Record 29 of Set 10 | buritizeiro
# Processing Record 30 of Set 10 | atbasar
# Processing Record 31 of Set 10 | itarema
# Processing Record 32 of Set 10 | bongandanga
# Processing Record 33 of Set 10 | antigonish
# Processing Record 34 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 10 | carnarvon
# Processing Record 36 of Set 10 | quatre cocos
# Processing Record 37 of Set 10 | davenda
# Processing Record 38 of Set 10 | zakamensk
# Processing Record 39 of Set 10 | churapcha
# Processing Record 40 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 10 | jinji
# Processing Record 42 of Set 10 | auki
# Processing Record 43 of Set 10 | nizhneangarsk
# Processing Record 44 of Set 10 | kruisfontein
# Processing Record 45 of Set 10 | poum
# Processing Record 46 of Set 10 | babu
# Processing Record 47 of Set 10 | kaberamaido
# Processing Record 48 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 10 | dno
# Processing Record 50 of Set 10 | guerrero negro
# Processing Record 1 of Set 11 | palana
# Processing Record 2 of Set 11 | sibu
# Processing Record 3 of Set 11 | tambopata
# Processing Record 4 of Set 11 | khor
# Processing Record 5 of Set 11 | gorom-gorom
# Processing Record 6 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 11 | vigrestad
# Processing Record 8 of Set 11 | bossangoa
# Processing Record 9 of Set 11 | lobito
# Processing Record 10 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 11 | taltal
# Processing Record 12 of Set 11 | lam luk ka
# Processing Record 13 of Set 11 | ovalle
# Processing Record 14 of Set 11 | the valley
# Processing Record 15 of Set 11 | atar
# Processing Record 16 of Set 11 | yeppoon
# Processing Record 17 of Set 11 | yumen
# Processing Record 18 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 11 | hastings
# Processing Record 20 of Set 11 | barra do garcas
# Processing Record 21 of Set 11 | santa clara
# Processing Record 22 of Set 11 | bumba
# Processing Record 23 of Set 11 | mutsu
# Processing Record 24 of Set 11 | ilhabela
# Processing Record 25 of Set 11 | tawang
# Processing Record 26 of Set 11 | shizunai
# Processing Record 27 of Set 11 | bansang
# Processing Record 28 of Set 11 | murgab
# Processing Record 29 of Set 11 | la asuncion
# Processing Record 30 of Set 11 | vestmanna
# Processing Record 31 of Set 11 | hasaki
# Processing Record 32 of Set 11 | humaita
# Processing Record 33 of Set 11 | doha
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | benito juarez
# Processing Record 36 of Set 11 | san lawrenz
# Processing Record 37 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 11 | chegdomyn
# Processing Record 39 of Set 11 | kamenka
# Processing Record 40 of Set 11 | porto belo
# Processing Record 41 of Set 11 | khani
# Processing Record 42 of Set 11 | smithers
# Processing Record 43 of Set 11 | bom jesus
# Processing Record 44 of Set 11 | tunceli
# Processing Record 45 of Set 11 | sergeyevka
# Processing Record 46 of Set 11 | mayskiy
# Processing Record 47 of Set 11 | ostrovnoy
# Processing Record 48 of Set 11 | behbahan
# Processing Record 49 of Set 11 | moose jaw
# Processing Record 50 of Set 11 | roma
# Processing Record 1 of Set 12 | samoded
# Processing Record 2 of Set 12 | shelbyville
# Processing Record 3 of Set 12 | rockland
# Processing Record 4 of Set 12 | mao
# Processing Record 5 of Set 12 | palmerston
# Processing Record 6 of Set 12 | bandarbeyla
# Processing Record 7 of Set 12 | tezu
# Processing Record 8 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 12 | nishihara
# Processing Record 10 of Set 12 | sribne
# Processing Record 11 of Set 12 | kavaratti
# Processing Record 12 of Set 12 | chenzhou
# Processing Record 13 of Set 12 | timmins
# Processing Record 14 of Set 12 | cururupu
# Processing Record 15 of Set 12 | bowen
# Processing Record 16 of Set 12 | diu
# Processing Record 17 of Set 12 | paranhos
# Processing Record 18 of Set 12 | san patricio
# Processing Record 19 of Set 12 | la ronge
# Processing Record 20 of Set 12 | san ramon de la nueva oran
# Processing Record 21 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 12 | otjiwarongo
# Processing Record 23 of Set 12 | la union
# Processing Record 24 of Set 12 | maragogi
# Processing Record 25 of Set 12 | iskateley
# Processing Record 26 of Set 12 | socorro
# Processing Record 27 of Set 12 | parrita
# Processing Record 28 of Set 12 | nohar
# Processing Record 29 of Set 12 | mugla
# Processing Record 30 of Set 12 | tual
# Processing Record 31 of Set 12 | ratangarh
# Processing Record 32 of Set 12 | tilichiki
# Processing Record 33 of Set 12 | siteki
# Processing Record 34 of Set 12 | ngerengere
# Processing Record 35 of Set 12 | katherine
# Processing Record 36 of Set 12 | baykit
# Processing Record 37 of Set 12 | nova olinda do norte
# Processing Record 38 of Set 12 | iqaluit
# Processing Record 39 of Set 12 | belturbet
# Processing Record 40 of Set 12 | shimanovsk
# Processing Record 41 of Set 12 | paragominas
# Processing Record 42 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 12 | mancora
# Processing Record 44 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 12 | zabol
# Processing Record 46 of Set 12 | celestun
# Processing Record 47 of Set 12 | beloha
# Processing Record 48 of Set 12 | amga
# Processing Record 49 of Set 12 | kupang
# Processing Record 50 of Set 12 | north bend
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 3 of Set 13 | gazanjyk
# Processing Record 4 of Set 13 | soto la marina
# Processing Record 5 of Set 13 | sinnai
# Processing Record 6 of Set 13 | parana
# Processing Record 7 of Set 13 | antalaha
# Processing Record 8 of Set 13 | bulungu
# Processing Record 9 of Set 13 | batagay
# Processing Record 10 of Set 13 | zhaoqing
# Processing Record 11 of Set 13 | denpasar
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | ola
# Processing Record 14 of Set 13 | awjilah
# Processing Record 15 of Set 13 | jutai
# Processing Record 16 of Set 13 | ribeira brava
# Processing Record 17 of Set 13 | hofn
# Processing Record 18 of Set 13 | anadyr
# Processing Record 19 of Set 13 | wawa
# Processing Record 20 of Set 13 | kentau
# Processing Record 21 of Set 13 | shimoda
# Processing Record 22 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 23 of Set 13 | xining
# Processing Record 24 of Set 13 | muncar
# Processing Record 25 of Set 13 | guane
# Processing Record 26 of Set 13 | noumea
# Processing Record 27 of Set 13 | coquimbo
# Processing Record 28 of Set 13 | bonthe
# Processing Record 29 of Set 13 | itacare
# Processing Record 30 of Set 13 | aksay
# Processing Record 31 of Set 13 | yerofey pavlovich
# Processing Record 32 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 13 | hauterive
# Processing Record 34 of Set 13 | novyy urgal
# Processing Record 35 of Set 13 | tolga
# Processing Record 36 of Set 13 | garhi yasin
# Processing Record 37 of Set 13 | davidson
# Processing Record 38 of Set 13 | anton lizardo
# Processing Record 39 of Set 13 | maumere
# Processing Record 40 of Set 13 | dukat
# Processing Record 41 of Set 13 | rio gallegos
# Processing Record 42 of Set 13 | icod de los vinos
# Processing Record 43 of Set 13 | oktyabrskiy
# Processing Record 44 of Set 13 | solwezi
# Processing Record 45 of Set 13 | nizhnevartovsk
# Processing Record 46 of Set 13 | portsmouth
# Processing Record 47 of Set 13 | jalu
# Processing Record 48 of Set 13 | saint-jean-port-joli
# Processing Record 49 of Set 13 | tarko-sale
# Processing Record 50 of Set 13 | biak
# Processing Record 1 of Set 14 | aneho
# Processing Record 2 of Set 14 | alberdi
# Processing Record 3 of Set 14 | wenzhou
# Processing Record 4 of Set 14 | kudahuvadhoo
# Processing Record 5 of Set 14 | morgan city
# Processing Record 6 of Set 14 | teguldet
# Processing Record 7 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 14 | edd
# Processing Record 10 of Set 14 | obluche
# City not found. Skipping...
# Processing Record 11 of Set 14 | twin falls
# Processing Record 12 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 14 | siavonga
# Processing Record 14 of Set 14 | taksimo
# Processing Record 15 of Set 14 | tirlyanskiy
# Processing Record 16 of Set 14 | pathein
# Processing Record 17 of Set 14 | hokitika
# Processing Record 18 of Set 14 | constitucion
# Processing Record 19 of Set 14 | azacualpa
# Processing Record 20 of Set 14 | chebsara
# Processing Record 21 of Set 14 | sambava
# Processing Record 22 of Set 14 | mahuva
# Processing Record 23 of Set 14 | lanzhou
# Processing Record 24 of Set 14 | davila
# Processing Record 25 of Set 14 | bjornevatn
# Processing Record 26 of Set 14 | olinda
# Processing Record 27 of Set 14 | alot
# Processing Record 28 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 14 | minab
# Processing Record 30 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 14 | namwala
# Processing Record 32 of Set 14 | eureka
# Processing Record 33 of Set 14 | maniitsoq
# Processing Record 34 of Set 14 | ashland
# Processing Record 35 of Set 14 | rivera
# Processing Record 36 of Set 14 | kulob
# Processing Record 37 of Set 14 | kieta
# Processing Record 38 of Set 14 | dakar
# Processing Record 39 of Set 14 | iquique
# Processing Record 40 of Set 14 | manado
# Processing Record 41 of Set 14 | ballina
# Processing Record 42 of Set 14 | amapa
# Processing Record 43 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 14 | liboran
# Processing Record 45 of Set 14 | nara
# Processing Record 46 of Set 14 | kontagora
# Processing Record 47 of Set 14 | morehead
# Processing Record 48 of Set 14 | puro
# Processing Record 49 of Set 14 | mandalgovi
# Processing Record 50 of Set 14 | surt
# Processing Record 1 of Set 15 | quelimane
# Processing Record 2 of Set 15 | sabha
# Processing Record 3 of Set 15 | chiang klang
# Processing Record 4 of Set 15 | whyalla
# Processing Record 5 of Set 15 | ulladulla
# Processing Record 6 of Set 15 | guayaramerin
# Processing Record 7 of Set 15 | kidal
# Processing Record 8 of Set 15 | aconibe
# Processing Record 9 of Set 15 | klyuchi
# Processing Record 10 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 11 of Set 15 | samarai
# Processing Record 12 of Set 15 | benalla
# Processing Record 13 of Set 15 | makakilo city
# Processing Record 14 of Set 15 | svetlyy
# Processing Record 15 of Set 15 | pirovskoye
# Processing Record 16 of Set 15 | frankfort
# Processing Record 17 of Set 15 | lexington
# Processing Record 18 of Set 15 | batticaloa
# Processing Record 19 of Set 15 | ekhabi
# Processing Record 20 of Set 15 | kaliganj
# Processing Record 21 of Set 15 | roald
# Processing Record 22 of Set 15 | buriti bravo
# Processing Record 23 of Set 15 | singkang
# Processing Record 24 of Set 15 | ayagoz
# Processing Record 25 of Set 15 | moose factory
# Processing Record 26 of Set 15 | emba
# Processing Record 27 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 28 of Set 15 | kuytun
# Processing Record 29 of Set 15 | liverpool
# Processing Record 30 of Set 15 | solnechnyy
# Processing Record 31 of Set 15 | sioux lookout
# Processing Record 32 of Set 15 | guamuchil
# Processing Record 33 of Set 15 | tanete
# Processing Record 34 of Set 15 | jibuti
# Processing Record 35 of Set 15 | nizwa
# Processing Record 36 of Set 15 | hervey bay
# Processing Record 37 of Set 15 | henties bay
# Processing Record 38 of Set 15 | canberra
# Processing Record 39 of Set 15 | anloga
# Processing Record 40 of Set 15 | aberdeen
# Processing Record 41 of Set 15 | ucluelet
# Processing Record 42 of Set 15 | emerald
# Processing Record 43 of Set 15 | alyangula
# Processing Record 44 of Set 15 | sayyan
# Processing Record 45 of Set 15 | balabac
# Processing Record 46 of Set 15 | novyye burasy
# Processing Record 47 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 15 | el paujil
# Processing Record 49 of Set 15 | medicine hat
# Processing Record 50 of Set 15 | sosua
# Processing Record 1 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 16 | odienne
# Processing Record 3 of Set 16 | santa
# Processing Record 4 of Set 16 | rondonopolis
# Processing Record 5 of Set 16 | magugu
# Processing Record 6 of Set 16 | ried
# Processing Record 7 of Set 16 | avera
# Processing Record 8 of Set 16 | spisska bela
# Processing Record 9 of Set 16 | butembo
# Processing Record 10 of Set 16 | takoradi
# Processing Record 11 of Set 16 | krizevci
# Processing Record 12 of Set 16 | jacksonville
# Processing Record 13 of Set 16 | omsukchan
# Processing Record 14 of Set 16 | ikongo
# Processing Record 15 of Set 16 | umred
# Processing Record 16 of Set 16 | washougal
# Processing Record 17 of Set 16 | okhotsk
# Processing Record 18 of Set 16 | yenagoa
# Processing Record 19 of Set 16 | shumikha
# Processing Record 20 of Set 16 | erenhot
# Processing Record 21 of Set 16 | roshchino
# Processing Record 22 of Set 16 | teknaf
# Processing Record 23 of Set 16 | tiznit
# Processing Record 24 of Set 16 | kankavli
# City not found. Skipping...
# Processing Record 25 of Set 16 | kampong chhnang
# Processing Record 26 of Set 16 | vardo
# Processing Record 27 of Set 16 | niigata
# Processing Record 28 of Set 16 | cabinda
# Processing Record 29 of Set 16 | pauini
# Processing Record 30 of Set 16 | watrous
# Processing Record 31 of Set 16 | bolshoy uluy
# City not found. Skipping...
# Processing Record 32 of Set 16 | barao de melgaco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check that the product is a list of dictionaries
#city_data

# %% [markdown]
# # Convert results into a data frame

# %%
cities_df = pd.DataFrame(city_data)
cities_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Korla      CN  41.7597   86.1469     77.56        20         100
# 1   Ribeira Grande      PT  38.5167  -28.7000     66.90        67          94
# 2    Saint Anthony      US  45.0205  -93.2180     91.74        20           1
# 3        Cape Town      ZA -33.9258   18.4232     57.11        98          18
# 4  Haines Junction      CA  60.7522 -137.5108     67.95        34         100
# 5             Chuy      UY -33.6971  -53.4616     50.32        85          59
# 6        Rongcheng      CN  30.6340  117.8517     69.64        98         100
# 7    Novaya Zaimka      RU  56.4857   66.9241     44.58        67          51
# 8     Puerto Ayora      EC  -0.7393  -90.3518     76.96        98          53
# 9           Nyimba      ZM -14.5566   30.8149     67.50        47         100
#
#    Wind Speed           Description
# 0        5.41       overcast clouds
# 1        5.59       overcast clouds
# 2        4.00             clear sky
# 3        3.44                   fog
# 4        2.30       overcast clouds
# 5        7.45         broken clouds
# 6        2.28  heavy intensity rain
# 7        7.43         broken clouds
# 8        7.00            light rain
# 9        6.08       overcast clouds

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'
cities_df.to_csv(output_data_file,index_label='City_ID')
